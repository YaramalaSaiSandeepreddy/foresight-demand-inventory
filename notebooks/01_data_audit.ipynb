# %% [markdown]
# # FORESIGHT — Data Audit
# Run `python src/pipeline.py --raw work/extracted/retail_clean_dataset/sales_transactions.csv`. The reproducible audit is saved to `reports/data_quality_report.md`.
