# %% [markdown]
# # Seasonal-Naive Baseline
# Implemented reproducibly in `src/forecast.py`; it uses an 8-week lag because the resulting weekly history is under the conventional 52-week threshold for every evaluation SKU.
